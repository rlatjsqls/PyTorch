# %% [markdown]
# #1. 숫자 필기 데이터 소개

# %%
#matplotlib inline
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
digits = load_digits()

# %%
print(digits.images[0])
# Out:
# [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]

# %%
print(digits.target[0])
# Out:
# 0

# %%
print('전체샘플의 수 : {}'.format(len(digits.images)))
# Out:
# 전체샘플의 수 : 1797

# %%
images_and_labels = list(zip(digits.images, digits.target))
for index, (image, label) in enumerate(images_and_labels[:5]):
    plt.subplot(2,5,index + 1)
    plt.axis('off')
    plt.imshow(image, cmap=plt.cm.gray_r,interpolation = 'nearest')
    plt.title('sample %i'% label)

# %%
for i in range(5):
    print(i,'번 인덱스 샘플의 레이블 :',digits.target[i])
# Out:
# 0 번 인덱스 샘플의 레이블 : 0
# 1 번 인덱스 샘플의 레이블 : 1
# 2 번 인덱스 샘플의 레이블 : 2
# 3 번 인덱스 샘플의 레이블 : 3
# 4 번 인덱스 샘플의 레이블 : 4

# %%
print(digits.data[0])
# Out:
# [ 0.  0.  5. 13.  9.  1.  0.  0.  0.  0. 13. 15. 10. 15.  5.  0.  0.  3.
#  15.  2.  0. 11.  8.  0.  0.  4. 12.  0.  0.  8.  8.  0.  0.  5.  8.  0.
#   0.  9.  8.  0.  0.  4. 11.  0.  1. 12.  7.  0.  0.  2. 14.  5. 10. 12.
#   0.  0.  0.  0.  6. 13. 10.  0.  0.  0.]

# %%
X = digits.data
Y = digits.target

# %% [markdown]
# #2. 다층 퍼셉트론 분류기 만들기

# %%
import torch
import torch.nn as nn
from torch import optim

# %%
model = nn.Sequential(
    nn.Linear(64,32),
    nn.ReLU(),
    nn.Linear(32,16),
    nn.ReLU(),
    nn.Linear(16,10)
)

# %%
X = torch.tensor(X, dtype=torch.float32)
Y = torch.tensor(Y, dtype=torch.int64)

# %%
loss_fn = nn.CrossEntropyLoss()

# %%
optimizer = optim.Adam(model.parameters())

# %%
losses = []

# %%
for epoch in range(100):
  optimizer.zero_grad()
  y_pred = model(X) # forwar 연산
  loss = loss_fn(y_pred, Y)
  loss.backward()
  optimizer.step()

  if epoch % 10 == 0:
    print('Epoch {:4d}/{} Cost: {:.6f}'.format(
            epoch, 100, loss.item()
        ))

  losses.append(loss.item())
# Out:
# Epoch    0/100 Cost: 2.376192
# Epoch   10/100 Cost: 2.065765
# Epoch   20/100 Cost: 1.796929
# Epoch   30/100 Cost: 1.522509
# Epoch   40/100 Cost: 1.252433
# Epoch   50/100 Cost: 0.994800
# Epoch   60/100 Cost: 0.768057
# Epoch   70/100 Cost: 0.588259
# Epoch   80/100 Cost: 0.450753
# Epoch   90/100 Cost: 0.347983

# %%
plt.plot(losses)
