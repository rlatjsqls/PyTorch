# %% [markdown]
# #1. 커스텀 데이터셋(Custom Dataset)

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self):
        pass
        #데이터셋의 전처리를 해주는부분
    
    def __len__(self):
        pass
        #데이터셋의 길이. 즉, 총 샘플의 수를 적어주는 부분

    def __getitem__(self):
        pass
        #데이터셋에서 특정 1개의 샘플을 가져오는 함수

# %% [markdown]
# #2. 커스텀 데이터셋(Custom Dataset)으로 선형 회귀 구현하기

# %%
class CustomDataset(Dataset):
    def __init__(self):
        self.x_data = [[73, 80, 75],
                   [93, 88, 93],
                   [89, 91, 90],
                   [96, 98, 100],
                   [73, 66, 70]]
        self.y_data = [[152], [185], [180], [196], [142]]
    
    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        x = torch.FloatTensor(self.x_data[idx])
        y = torch.FloatTensor(self.y_data[idx])
        return x, y

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = torch.nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs+1):
    for batch_idx, samples in enumerate(dataloader):
        x_train, y_train = samples
        #H(x)계산
        prediction = model(x_train)

        #cost계산
        cost = F.mse_loss(prediction, y_train)

        #cost로 H(x)계산
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

        print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 12024.086914
# Epoch    0/20 Batch 2/3 Cost: 4658.150879
# Epoch    0/20 Batch 3/3 Cost: 1897.545166
# Epoch    1/20 Batch 1/3 Cost: 319.782196
# Epoch    1/20 Batch 2/3 Cost: 116.242294
# Epoch    1/20 Batch 3/3 Cost: 25.137671
# Epoch    2/20 Batch 1/3 Cost: 42.371613
# Epoch    2/20 Batch 2/3 Cost: 0.830478
# Epoch    2/20 Batch 3/3 Cost: 3.557290
# Epoch    3/20 Batch 1/3 Cost: 26.027431
# Epoch    3/20 Batch 2/3 Cost: 6.708385
# Epoch    3/20 Batch 3/3 Cost: 0.451888
# Epoch    4/20 Batch 1/3 Cost: 12.060615
# Epoch    4/20 Batch 2/3 Cost: 5.799213
# Epoch    4/20 Batch 3/3 Cost: 8.424397
# Epoch    5/20 Batch 1/3 Cost: 1.888334
# Epoch    5/20 Batch 2/3 Cost: 13.578435
# Epoch    5/20 Batch 3/3 Cost: 11.568884
# Epoch    6/20 Batch 1/3 Cost: 11.011309
# Epoch    6/20 Batch 2/3 Cost: 9.884809
# Epoch    6/20 Batch 3/3 Cost: 7.205853
# Epoch    7/20 Batch 1/3 Cost: 6.081373
# Epoch    7/20 Batch 2/3 Cost: 8.308695
# Epoch    7/20 Batch 3/3 Cost: 12.992584
# Epoch    8/20 Batch 1/3 Cost: 3.251726
# Epoch    8/20 Batch 2/3 Cost: 12.282213
# Epoch    8/20 Batch 3/3 Cost: 10.289748
# Epoch    9/20 Batch 1/3 Cost: 11.898070
# Epoch    9/20 Batch 2/3 Cost: 5.305050
# Epoch    9/20 Batch 3/3 Cost: 4.941354
# Epoch   10/20 Batch 1/3 Cost: 3.738039
# Epoch   10/20 Batch 2/3 Cost: 7.981692
# Epoch   10/20 Batch 3/3 Cost: 17.526852
# Epoch   11/20 Batch 1/3 Cost: 5.046501
# Epoch   11/20 Batch 2/3 Cost: 11.707611
# Epoch   11/20 Batch 3/3 Cost: 6.533837
# Epoch   12/20 Batch 1/3 Cost: 1.085941
# Epoch   12/20 Batch 2/3 Cost: 9.256611
# Epoch   12/20 Batch 3/3 Cost: 18.829741
# Epoch   13/20 Batch 1/3 Cost: 8.389265
# Epoch   13/20 Batch 2/3 Cost: 5.718637
# Epoch   13/20 Batch 3/3 Cost: 18.477299
# Epoch   14/20 Batch 1/3 Cost: 8.914223
# Epoch   14/20 Batch 2/3 Cost: 4.714334
# Epoch   14/20 Batch 3/3 Cost: 12.068245
# Epoch   15/20 Batch 1/3 Cost: 8.373610
# Epoch   15/20 Batch 2/3 Cost: 9.508317
# Epoch   15/20 Batch 3/3 Cost: 2.846369
# Epoch   16/20 Batch 1/3 Cost: 8.414257
# Epoch   16/20 Batch 2/3 Cost: 9.530439
# Epoch   16/20 Batch 3/3 Cost: 2.805737
# Epoch   17/20 Batch 1/3 Cost: 2.856411
# Epoch   17/20 Batch 2/3 Cost: 20.817577
# Epoch   17/20 Batch 3/3 Cost: 5.427557
# Epoch   18/20 Batch 1/3 Cost: 12.298599
# Epoch   18/20 Batch 2/3 Cost: 5.367289
# Epoch   18/20 Batch 3/3 Cost: 3.445313
# Epoch   19/20 Batch 1/3 Cost: 2.538926
# Epoch   19/20 Batch 2/3 Cost: 21.649487
# Epoch   19/20 Batch 3/3 Cost: 4.304599
# Epoch   20/20 Batch 1/3 Cost: 9.839788
# Epoch   20/20 Batch 2/3 Cost: 7.661767
# Epoch   20/20 Batch 3/3 Cost: 2.746046

# %%
new_var = torch.FloatTensor([[73,80,75]])
pred_y = model(new_var)
print("훈련후 예측값 : ", pred_y)
# Out:
# 훈련후 예측값 :  tensor([[154.2135]], grad_fn=<AddmmBackward0>)
